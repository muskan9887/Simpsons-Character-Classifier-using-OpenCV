# %% [markdown]
# <a href="https://colab.research.google.com/github/muskan9887/Simpsons-Character-Classifier-using-OpenCV/blob/main/Cv2_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
import numpy as np
from google.colab.patches import cv2_imshow
import matplotlib.pyplot as plt

# %% [markdown]
# ### Histogram Computation

# %%
img = cv2.imread("/content/cat.jpeg")
reimg=cv2.resize(img,(250,250))
cv2_imshow(reimg)
# Out:
# <PIL.Image.Image image mode=RGB size=250x250>

# %%
gray= cv2.cvtColor(reimg,cv2.COLOR_BGR2GRAY)
cv2_imshow(gray)

gray_hist = cv2.calcHist([gray],[0],None,[250],[0,250])

plt.figure()
plt.title("Grayscale Histogram")
plt.xlabel("Bins")
plt.ylabel("# of Pixels")
plt.plot(gray_hist)
plt.xlim([0,256])
plt.show()
# Out:
# <PIL.Image.Image image mode=L size=250x250>

# %% [markdown]
# ### Thresholding/Binarizing Images

# %%
gray= cv2.cvtColor(reimg,cv2.COLOR_BGR2GRAY)
cv2_imshow(gray)
# Out:
# <PIL.Image.Image image mode=L size=250x250>

# %%
#simple thresh
threshold,thresh = cv2.threshold(gray,150,255,cv2.THRESH_BINARY)
cv2_imshow(thresh)
# Out:
# <PIL.Image.Image image mode=L size=250x250>

# %%
#adaptive threshold

thresh = cv2.adaptiveThreshold(gray,255,cv2.ADAPTIVE_THRESH_GAUSSIAN_C,cv2.THRESH_BINARY,115,1)
cv2_imshow(thresh)
# Out:
# <PIL.Image.Image image mode=L size=250x250>

# %% [markdown]
# ### Edge Detection

# %%
#laplaction

laplacian = cv2.Laplacian(gray,cv2.CV_64F)
cv2_imshow(laplacian)
# Out:
# <PIL.Image.Image image mode=L size=250x250>

# %%
#Sobel
sobelx = cv2.Sobel(gray,cv2.CV_64F,1,0,ksize=5)
sobely = cv2.Sobel(gray,cv2.CV_64F,0,1,ksize=5)
cv2_imshow(sobelx)
cv2_imshow(sobely)
# Out:
# <PIL.Image.Image image mode=L size=250x250>
# <PIL.Image.Image image mode=L size=250x250>

# %% [markdown]
# ### Face Detection using Haar Cascades-in next notebook
