# %% [markdown]
# <a href="https://colab.research.google.com/github/muskan9887/Simpsons-Character-Classifier-using-OpenCV/blob/main/Face_detection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
import urllib.request

# Download the Haar Cascade XML file for face detection
url = 'https://github.com/opencv/opencv/raw/master/data/haarcascades/haarcascade_frontalface_default.xml'
urllib.request.urlretrieve(url, 'haarcascade_frontalface_default.xml')

# Load the Haar Cascade
face_cascade = cv2.CascadeClassifier('haarcascade_frontalface_default.xml')

# Example usage: Detect faces in an image
img = cv2.imread('/content/aish.jpeg')
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
faces = face_cascade.detectMultiScale(gray, 1.1, 4)

# Draw rectangles around the faces
for (x, y, w, h) in faces:
    cv2.rectangle(img, (x, y), (x+w, y+h), (255, 0, 0), 2)

# Display the output
from google.colab.patches import cv2_imshow
cv2_imshow(img)
print(len(faces))
# Out:
# <PIL.Image.Image image mode=RGB size=174x290>
# 1

# %%
reimg1 = cv2.imread("/content/img.jpeg")
gray1 = cv2.cvtColor(reimg1, cv2.COLOR_BGR2GRAY)
# Apply histogram equalization
gray1 = cv2.equalizeHist(gray1)

# Detect faces
faces1 = face_cascade.detectMultiScale(gray1, scaleFactor=1.1, minNeighbors=1)

# Draw rectangles around the faces
for (x, y, w, h) in faces1:
    cv2.rectangle(reimg1, (x, y), (x + w, y + h), (255, 0, 0), 2)

# Display the output
cv2_imshow(reimg1)
print(f"Number of faces detected: {len(faces1)}")
# Out:
# <PIL.Image.Image image mode=RGB size=225x225>
# Number of faces detected: 1

# %% [markdown]
# ### We have to fine tune the model for better Face Detection
